# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 753

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat=city_weather["coord"]["lat"]
        city_lng=city_weather["coord"]["lon"]
        city_max_temp=city_weather["main"]["temp_max"]
        city_humidity=city_weather["main"]["humidity"]
        city_clouds=city_weather["clouds"]["all"]
        city_wind=city_weather["wind"]["speed"]
        city_country=city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_description})
    
    # If an error is experienced, skip the city
        print('working')
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hasaki
# working
# Processing Record 2 of Set 1 | omsukchan
# working
# Processing Record 3 of Set 1 | punta arenas
# working
# Processing Record 4 of Set 1 | puerto ayora
# working
# Processing Record 5 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 1 | hobart
# working
# Processing Record 7 of Set 1 | sitka
# working
# Processing Record 8 of Set 1 | new norfolk
# working
# Processing Record 9 of Set 1 | nikolskoye
# working
# Processing Record 10 of Set 1 | rikitea
# working
# Processing Record 11 of Set 1 | ushuaia
# working
# Processing Record 12 of Set 1 | mataura
# working
# Processing Record 13 of Set 1 | marsa matruh
# working
# Processing Record 14 of Set 1 | merauke
# working
# Processing Record 15 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 1 | lasa
# working
# Processing Record 17 of Set 1 | wiang sa
# working
# Processing Record 18 of Set 1 | pevek
# working
# Processing Record 19 of Set 1 | ribeira grande
# working
# Processing Record 20 of Set 1 | busselton
# working
# Processing Record 21 of Set 1 | chokurdakh
# working
# Processing Record 22 of Set 1 | barrow
# working
# Processing Record 23 of Set 1 | fort nelson
# working
# Processing Record 24 of Set 1 | isangel
# working
# Processing Record 25 of Set 1 | hermanus
# working
# Processing Record 26 of Set 1 | kysyl-syr
# working
# Processing Record 27 of Set 1 | gizo
# working
# Processing Record 28 of Set 1 | ulladulla
# working
# Processing Record 29 of Set 1 | kachug
# working
# Processing Record 30 of Set 1 | dingle
# working
# Processing Record 31 of Set 1 | sakhnovshchyna
# working
# Processing Record 32 of Set 1 | cape town
# working
# Processing Record 33 of Set 1 | torbay
# working
# Processing Record 34 of Set 1 | butaritari
# working
# Processing Record 35 of Set 1 | teya
# working
# Processing Record 36 of Set 1 | valdivia
# working
# Processing Record 37 of Set 1 | saskylakh
# working
# Processing Record 38 of Set 1 | mbeya
# working
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | mehamn
# working
# Processing Record 41 of Set 1 | ketchikan
# working
# Processing Record 42 of Set 1 | newport
# working
# Processing Record 43 of Set 1 | mataram
# working
# Processing Record 44 of Set 1 | vestmannaeyjar
# working
# Processing Record 45 of Set 1 | atuona
# working
# Processing Record 46 of Set 1 | sorland
# working
# Processing Record 47 of Set 1 | jamestown
# working
# Processing Record 48 of Set 1 | tasiilaq
# working
# Processing Record 49 of Set 1 | leningradskiy
# working
# Processing Record 50 of Set 1 | savinka
# working
# Processing Record 1 of Set 2 | ibra
# working
# Processing Record 2 of Set 2 | albany
# working
# Processing Record 3 of Set 2 | lebu
# working
# Processing Record 4 of Set 2 | ilulissat
# working
# Processing Record 5 of Set 2 | bathsheba
# working
# Processing Record 6 of Set 2 | ust-koksa
# working
# Processing Record 7 of Set 2 | hilo
# working
# Processing Record 8 of Set 2 | khatanga
# working
# Processing Record 9 of Set 2 | yian
# City not found. Skipping...
# Processing Record 10 of Set 2 | yellowknife
# working
# Processing Record 11 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 2 | east london
# working
# Processing Record 13 of Set 2 | coquimbo
# working
# Processing Record 14 of Set 2 | tuktoyaktuk
# working
# Processing Record 15 of Set 2 | katsuura
# working
# Processing Record 16 of Set 2 | colon
# working
# Processing Record 17 of Set 2 | kajaani
# working
# Processing Record 18 of Set 2 | airai
# working
# Processing Record 19 of Set 2 | palora
# working
# Processing Record 20 of Set 2 | chuy
# working
# Processing Record 21 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 2 | taicheng
# working
# Processing Record 23 of Set 2 | lorengau
# working
# Processing Record 24 of Set 2 | ko samui
# working
# Processing Record 25 of Set 2 | gimli
# working
# Processing Record 26 of Set 2 | ponta delgada
# working
# Processing Record 27 of Set 2 | aksarka
# working
# Processing Record 28 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 29 of Set 2 | caravelas
# working
# Processing Record 30 of Set 2 | surt
# working
# Processing Record 31 of Set 2 | noyabrsk
# working
# Processing Record 32 of Set 2 | manzini
# working
# Processing Record 33 of Set 2 | praia da vitoria
# working
# Processing Record 34 of Set 2 | avarua
# working
# Processing Record 35 of Set 2 | bluff
# working
# Processing Record 36 of Set 2 | kaabong
# working
# Processing Record 37 of Set 2 | cherskiy
# working
# Processing Record 38 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 2 | berlevag
# working
# Processing Record 40 of Set 2 | cockburn town
# working
# Processing Record 41 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 2 | orlik
# working
# Processing Record 43 of Set 2 | puerto madryn
# working
# Processing Record 44 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 2 | bambous virieux
# working
# Processing Record 46 of Set 2 | ankazobe
# working
# Processing Record 47 of Set 2 | clyde river
# working
# Processing Record 48 of Set 2 | namatanai
# working
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | la tuque
# working
# Processing Record 1 of Set 3 | batsfjord
# working
# Processing Record 2 of Set 3 | borogontsy
# working
# Processing Record 3 of Set 3 | urumqi
# working
# Processing Record 4 of Set 3 | saint-philippe
# working
# Processing Record 5 of Set 3 | joensuu
# working
# Processing Record 6 of Set 3 | monrovia
# working
# Processing Record 7 of Set 3 | dolores
# working
# Processing Record 8 of Set 3 | talhar
# working
# Processing Record 9 of Set 3 | nisia floresta
# working
# Processing Record 10 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | comodoro rivadavia
# working
# Processing Record 12 of Set 3 | khangarh
# working
# Processing Record 13 of Set 3 | meulaboh
# working
# Processing Record 14 of Set 3 | tuatapere
# working
# Processing Record 15 of Set 3 | maragogi
# working
# Processing Record 16 of Set 3 | upernavik
# working
# Processing Record 17 of Set 3 | talavera
# working
# Processing Record 18 of Set 3 | port elizabeth
# working
# Processing Record 19 of Set 3 | yumen
# working
# Processing Record 20 of Set 3 | port hawkesbury
# working
# Processing Record 21 of Set 3 | falealupo
# City not found. Skipping...
# Processing Record 22 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 3 | itoman
# working
# Processing Record 24 of Set 3 | kemin
# working
# Processing Record 25 of Set 3 | vaini
# working
# Processing Record 26 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 27 of Set 3 | ngunguru
# working
# Processing Record 28 of Set 3 | santa cruz
# working
# Processing Record 29 of Set 3 | inuvik
# working
# Processing Record 30 of Set 3 | bundaberg
# working
# Processing Record 31 of Set 3 | kralendijk
# working
# Processing Record 32 of Set 3 | durban
# working
# Processing Record 33 of Set 3 | tual
# working
# Processing Record 34 of Set 3 | hamilton
# working
# Processing Record 35 of Set 3 | bengkulu
# working
# Processing Record 36 of Set 3 | castro
# working
# Processing Record 37 of Set 3 | port hardy
# working
# Processing Record 38 of Set 3 | yanam
# working
# Processing Record 39 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 3 | henties bay
# working
# Processing Record 41 of Set 3 | atar
# working
# Processing Record 42 of Set 3 | qaanaaq
# working
# Processing Record 43 of Set 3 | kodiak
# working
# Processing Record 44 of Set 3 | singkang
# working
# Processing Record 45 of Set 3 | kapaa
# working
# Processing Record 46 of Set 3 | huarmey
# working
# Processing Record 47 of Set 3 | sambava
# working
# Processing Record 48 of Set 3 | muskegon
# working
# Processing Record 49 of Set 3 | ajaccio
# working
# Processing Record 50 of Set 3 | okakarara
# working
# Processing Record 1 of Set 4 | ponta do sol
# working
# Processing Record 2 of Set 4 | ahipara
# working
# Processing Record 3 of Set 4 | black diamond
# working
# Processing Record 4 of Set 4 | bredasdorp
# working
# Processing Record 5 of Set 4 | barcelona
# working
# Processing Record 6 of Set 4 | forestville
# working
# Processing Record 7 of Set 4 | caruray
# working
# Processing Record 8 of Set 4 | revda
# working
# Processing Record 9 of Set 4 | magrath
# working
# Processing Record 10 of Set 4 | aksehir
# working
# Processing Record 11 of Set 4 | aden
# working
# Processing Record 12 of Set 4 | dakoro
# working
# Processing Record 13 of Set 4 | ocean city
# working
# Processing Record 14 of Set 4 | zhigalovo
# working
# Processing Record 15 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 16 of Set 4 | sobolevo
# working
# Processing Record 17 of Set 4 | mount isa
# working
# Processing Record 18 of Set 4 | souillac
# working
# Processing Record 19 of Set 4 | halifax
# working
# Processing Record 20 of Set 4 | yunyang
# working
# Processing Record 21 of Set 4 | urusha
# working
# Processing Record 22 of Set 4 | georgetown
# working
# Processing Record 23 of Set 4 | north bend
# working
# Processing Record 24 of Set 4 | san patricio
# working
# Processing Record 25 of Set 4 | ornskoldsvik
# working
# Processing Record 26 of Set 4 | alugan
# working
# Processing Record 27 of Set 4 | san andres
# working
# Processing Record 28 of Set 4 | severo-kurilsk
# working
# Processing Record 29 of Set 4 | narsaq
# working
# Processing Record 30 of Set 4 | saint-joseph
# working
# Processing Record 31 of Set 4 | rio grande
# working
# Processing Record 32 of Set 4 | sao filipe
# working
# Processing Record 33 of Set 4 | pangnirtung
# working
# Processing Record 34 of Set 4 | yamada
# working
# Processing Record 35 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 36 of Set 4 | solnechnyy
# working
# Processing Record 37 of Set 4 | balkanabat
# working
# Processing Record 38 of Set 4 | general pico
# working
# Processing Record 39 of Set 4 | joshimath
# working
# Processing Record 40 of Set 4 | port alfred
# working
# Processing Record 41 of Set 4 | parana
# working
# Processing Record 42 of Set 4 | lavrentiya
# working
# Processing Record 43 of Set 4 | verkhoyansk
# working
# Processing Record 44 of Set 4 | sur
# working
# Processing Record 45 of Set 4 | brattvag
# working
# Processing Record 46 of Set 4 | cayenne
# working
# Processing Record 47 of Set 4 | cartagena
# working
# Processing Record 48 of Set 4 | bacalar
# working
# Processing Record 49 of Set 4 | pitimbu
# working
# Processing Record 50 of Set 4 | fairbanks
# working
# Processing Record 1 of Set 5 | belyy yar
# working
# Processing Record 2 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 5 | quelimane
# working
# Processing Record 4 of Set 5 | qaqortoq
# working
# Processing Record 5 of Set 5 | khani
# working
# Processing Record 6 of Set 5 | bogorodskoye
# working
# Processing Record 7 of Set 5 | dikson
# working
# Processing Record 8 of Set 5 | mahebourg
# working
# Processing Record 9 of Set 5 | uddevalla
# working
# Processing Record 10 of Set 5 | banda aceh
# working
# Processing Record 11 of Set 5 | manzhouli
# working
# Processing Record 12 of Set 5 | jijiga
# working
# Processing Record 13 of Set 5 | deputatskiy
# working
# Processing Record 14 of Set 5 | sao joao da barra
# working
# Processing Record 15 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 5 | puerto leguizamo
# working
# Processing Record 17 of Set 5 | port hedland
# working
# Processing Record 18 of Set 5 | maraba
# working
# Processing Record 19 of Set 5 | arraial do cabo
# working
# Processing Record 20 of Set 5 | divnomorskoye
# working
# Processing Record 21 of Set 5 | nanortalik
# working
# Processing Record 22 of Set 5 | kamina
# working
# Processing Record 23 of Set 5 | kruisfontein
# working
# Processing Record 24 of Set 5 | tigil
# working
# Processing Record 25 of Set 5 | cabatuan
# working
# Processing Record 26 of Set 5 | brae
# working
# Processing Record 27 of Set 5 | codrington
# working
# Processing Record 28 of Set 5 | akureyri
# working
# Processing Record 29 of Set 5 | hovd
# working
# Processing Record 30 of Set 5 | nome
# working
# Processing Record 31 of Set 5 | griffith
# working
# Processing Record 32 of Set 5 | srednekolymsk
# working
# Processing Record 33 of Set 5 | olinda
# working
# Processing Record 34 of Set 5 | kansk
# working
# Processing Record 35 of Set 5 | nouakchott
# working
# Processing Record 36 of Set 5 | iqaluit
# working
# Processing Record 37 of Set 5 | bad kissingen
# working
# Processing Record 38 of Set 5 | fortuna
# working
# Processing Record 39 of Set 5 | san cristobal
# working
# Processing Record 40 of Set 5 | kamenka
# working
# Processing Record 41 of Set 5 | quchan
# working
# Processing Record 42 of Set 5 | barranca
# working
# Processing Record 43 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 5 | kibre mengist
# working
# Processing Record 45 of Set 5 | gweta
# working
# Processing Record 46 of Set 5 | hambantota
# working
# Processing Record 47 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 5 | phaltan
# working
# Processing Record 49 of Set 5 | dukat
# working
# Processing Record 50 of Set 5 | zhanaozen
# working
# Processing Record 1 of Set 6 | cabo san lucas
# working
# Processing Record 2 of Set 6 | mora
# working
# Processing Record 3 of Set 6 | saint-augustin
# working
# Processing Record 4 of Set 6 | novyy urengoy
# working
# Processing Record 5 of Set 6 | avera
# working
# Processing Record 6 of Set 6 | morden
# working
# Processing Record 7 of Set 6 | wattegama
# working
# Processing Record 8 of Set 6 | tiguisan
# working
# Processing Record 9 of Set 6 | marquette
# working
# Processing Record 10 of Set 6 | chany
# working
# Processing Record 11 of Set 6 | kaitangata
# working
# Processing Record 12 of Set 6 | susanville
# working
# Processing Record 13 of Set 6 | hithadhoo
# working
# Processing Record 14 of Set 6 | tingi
# working
# Processing Record 15 of Set 6 | aklavik
# working
# Processing Record 16 of Set 6 | slonim
# working
# Processing Record 17 of Set 6 | faanui
# working
# Processing Record 18 of Set 6 | mar del plata
# working
# Processing Record 19 of Set 6 | queimados
# working
# Processing Record 20 of Set 6 | carnarvon
# working
# Processing Record 21 of Set 6 | petrinja
# working
# Processing Record 22 of Set 6 | bethel
# working
# Processing Record 23 of Set 6 | bowen
# working
# Processing Record 24 of Set 6 | port shepstone
# working
# Processing Record 25 of Set 6 | alice springs
# working
# Processing Record 26 of Set 6 | raudeberg
# working
# Processing Record 27 of Set 6 | san quintin
# working
# Processing Record 28 of Set 6 | rincon
# working
# Processing Record 29 of Set 6 | naze
# working
# Processing Record 30 of Set 6 | terrace
# working
# Processing Record 31 of Set 6 | pangkalanbuun
# working
# Processing Record 32 of Set 6 | luebo
# working
# Processing Record 33 of Set 6 | victoria
# working
# Processing Record 34 of Set 6 | xuanzhou
# working
# Processing Record 35 of Set 6 | hirara
# working
# Processing Record 36 of Set 6 | nantucket
# working
# Processing Record 37 of Set 6 | saint anthony
# working
# Processing Record 38 of Set 6 | cooma
# working
# Processing Record 39 of Set 6 | gudari
# working
# Processing Record 40 of Set 6 | paducah
# working
# Processing Record 41 of Set 6 | xining
# working
# Processing Record 42 of Set 6 | thompson
# working
# Processing Record 43 of Set 6 | winnemucca
# working
# Processing Record 44 of Set 6 | elizabeth city
# working
# Processing Record 45 of Set 6 | lagoa
# working
# Processing Record 46 of Set 6 | labuhan
# working
# Processing Record 47 of Set 6 | longyearbyen
# working
# Processing Record 48 of Set 6 | warrington
# working
# Processing Record 49 of Set 6 | intipuca
# working
# Processing Record 50 of Set 6 | ayan
# working
# Processing Record 1 of Set 7 | victor harbor
# working
# Processing Record 2 of Set 7 | maceio
# working
# Processing Record 3 of Set 7 | zarnesti
# working
# Processing Record 4 of Set 7 | buin
# working
# Processing Record 5 of Set 7 | ankazoabo
# working
# Processing Record 6 of Set 7 | salamiyah
# working
# Processing Record 7 of Set 7 | celestun
# working
# Processing Record 8 of Set 7 | san jeronimo
# working
# Processing Record 9 of Set 7 | pangoa
# working
# Processing Record 10 of Set 7 | huilong
# working
# Processing Record 11 of Set 7 | bilibino
# working
# Processing Record 12 of Set 7 | elizabethtown
# working
# Processing Record 13 of Set 7 | alice town
# working
# Processing Record 14 of Set 7 | chimoio
# working
# Processing Record 15 of Set 7 | vinh
# working
# Processing Record 16 of Set 7 | nacala
# working
# Processing Record 17 of Set 7 | cidreira
# working
# Processing Record 18 of Set 7 | port pirie
# working
# Processing Record 19 of Set 7 | marawi
# working
# Processing Record 20 of Set 7 | scottsbluff
# working
# Processing Record 21 of Set 7 | mayo
# working
# Processing Record 22 of Set 7 | kapit
# working
# Processing Record 23 of Set 7 | faya
# working
# Processing Record 24 of Set 7 | oga
# working
# Processing Record 25 of Set 7 | valparaiso
# working
# Processing Record 26 of Set 7 | mayumba
# working
# Processing Record 27 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 7 | xiaoweizhai
# working
# Processing Record 29 of Set 7 | portland
# working
# Processing Record 30 of Set 7 | belaya gora
# working
# Processing Record 31 of Set 7 | pangai
# working
# Processing Record 32 of Set 7 | nacogdoches
# working
# Processing Record 33 of Set 7 | san policarpo
# working
# Processing Record 34 of Set 7 | yeppoon
# working
# Processing Record 35 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 7 | kathmandu
# working
# Processing Record 37 of Set 7 | christchurch
# working
# Processing Record 38 of Set 7 | hereford
# working
# Processing Record 39 of Set 7 | laguna
# working
# Processing Record 40 of Set 7 | pontianak
# working
# Processing Record 41 of Set 7 | udachnyy
# working
# Processing Record 42 of Set 7 | santa cruz del sur
# working
# Processing Record 43 of Set 7 | grand gaube
# working
# Processing Record 44 of Set 7 | seddon
# working
# Processing Record 45 of Set 7 | chirongui
# working
# Processing Record 46 of Set 7 | norman wells
# working
# Processing Record 47 of Set 7 | high level
# working
# Processing Record 48 of Set 7 | houma
# working
# Processing Record 49 of Set 7 | jati
# working
# Processing Record 50 of Set 7 | klaksvik
# working
# Processing Record 1 of Set 8 | richards bay
# working
# Processing Record 2 of Set 8 | gusau
# working
# Processing Record 3 of Set 8 | sovetskiy
# working
# Processing Record 4 of Set 8 | visby
# working
# Processing Record 5 of Set 8 | punto fijo
# working
# Processing Record 6 of Set 8 | smoky lake
# working
# Processing Record 7 of Set 8 | tiksi
# working
# Processing Record 8 of Set 8 | nkoteng
# working
# Processing Record 9 of Set 8 | luderitz
# working
# Processing Record 10 of Set 8 | seinajoki
# working
# Processing Record 11 of Set 8 | esperance
# working
# Processing Record 12 of Set 8 | amahai
# working
# Processing Record 13 of Set 8 | flin flon
# working
# Processing Record 14 of Set 8 | katobu
# working
# Processing Record 15 of Set 8 | riyadh
# working
# Processing Record 16 of Set 8 | alofi
# working
# Processing Record 17 of Set 8 | yarmouth
# working
# Processing Record 18 of Set 8 | baykit
# working
# Processing Record 19 of Set 8 | baoning
# working
# Processing Record 20 of Set 8 | kununurra
# working
# Processing Record 21 of Set 8 | saint george
# working
# Processing Record 22 of Set 8 | lucea
# working
# Processing Record 23 of Set 8 | batemans bay
# working
# Processing Record 24 of Set 8 | saldanha
# working
# Processing Record 25 of Set 8 | mount gambier
# working
# Processing Record 26 of Set 8 | chute-aux-outardes
# working
# Processing Record 27 of Set 8 | coahuayana
# working
# Processing Record 28 of Set 8 | kisangani
# working
# Processing Record 29 of Set 8 | jalu
# working
# Processing Record 30 of Set 8 | jaunjelgava
# working
# Processing Record 31 of Set 8 | namerikawa
# working
# Processing Record 32 of Set 8 | half moon bay
# working
# Processing Record 33 of Set 8 | bozeman
# working
# Processing Record 34 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 35 of Set 8 | najran
# working
# Processing Record 36 of Set 8 | santa cruz cabralia
# working
# Processing Record 37 of Set 8 | mynay
# working
# Processing Record 38 of Set 8 | provideniya
# working
# Processing Record 39 of Set 8 | eisenerz
# working
# Processing Record 40 of Set 8 | lukulu
# working
# Processing Record 41 of Set 8 | aktau
# working
# Processing Record 42 of Set 8 | touros
# working
# Processing Record 43 of Set 8 | buzmeyin
# working
# Processing Record 44 of Set 8 | ancud
# working
# Processing Record 45 of Set 8 | atasu
# working
# Processing Record 46 of Set 8 | malanje
# working
# Processing Record 47 of Set 8 | chifeng
# working
# Processing Record 48 of Set 8 | kuvshinovo
# working
# Processing Record 49 of Set 8 | belturbet
# working
# Processing Record 50 of Set 8 | charlestown
# working
# Processing Record 1 of Set 9 | barra patuca
# working
# Processing Record 2 of Set 9 | segovia
# working
# Processing Record 3 of Set 9 | magistralnyy
# working
# Processing Record 4 of Set 9 | komsomolskiy
# working
# Processing Record 5 of Set 9 | guerrero negro
# working
# Processing Record 6 of Set 9 | tawang
# working
# Processing Record 7 of Set 9 | acarau
# working
# Processing Record 8 of Set 9 | mangrol
# working
# Processing Record 9 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 9 | bud
# working
# Processing Record 11 of Set 9 | yashkul
# working
# Processing Record 12 of Set 9 | dhidhdhoo
# working
# Processing Record 13 of Set 9 | abu jubayhah
# City not found. Skipping...
# Processing Record 14 of Set 9 | agara
# working
# Processing Record 15 of Set 9 | machali
# working
# Processing Record 16 of Set 9 | iisalmi
# working
# Processing Record 17 of Set 9 | sayyan
# working
# Processing Record 18 of Set 9 | calvinia
# working
# Processing Record 19 of Set 9 | kayasula
# working
# Processing Record 20 of Set 9 | buraydah
# working
# Processing Record 21 of Set 9 | vardo
# working
# Processing Record 22 of Set 9 | colac
# working
# Processing Record 23 of Set 9 | westport
# working
# Processing Record 24 of Set 9 | yingshang
# City not found. Skipping...
# Processing Record 25 of Set 9 | minot
# working
# Processing Record 26 of Set 9 | ende
# working
# Processing Record 27 of Set 9 | san-pedro
# working
# Processing Record 28 of Set 9 | port macquarie
# working
# Processing Record 29 of Set 9 | lazaro cardenas
# working
# Processing Record 30 of Set 9 | pisco
# working
# Processing Record 31 of Set 9 | kavaratti
# working
# Processing Record 32 of Set 9 | yulara
# working
# Processing Record 33 of Set 9 | viedma
# working
# Processing Record 34 of Set 9 | sechura
# working
# Processing Record 35 of Set 9 | flinders
# working
# Processing Record 36 of Set 9 | san vicente
# working
# Processing Record 37 of Set 9 | mount pleasant
# working
# Processing Record 38 of Set 9 | bambanglipuro
# working
# Processing Record 39 of Set 9 | vikulovo
# working
# Processing Record 40 of Set 9 | stornoway
# working
# Processing Record 41 of Set 9 | walvis bay
# working
# Processing Record 42 of Set 9 | kahului
# working
# Processing Record 43 of Set 9 | karasburg
# working
# Processing Record 44 of Set 9 | hirado
# working
# Processing Record 45 of Set 9 | gornopravdinsk
# working
# Processing Record 46 of Set 9 | garchitorena
# working
# Processing Record 47 of Set 9 | mao
# working
# Processing Record 48 of Set 9 | klyuchi
# working
# Processing Record 49 of Set 9 | pedernales
# working
# Processing Record 50 of Set 9 | bella union
# working
# Processing Record 1 of Set 10 | the valley
# working
# Processing Record 2 of Set 10 | gigmoto
# working
# Processing Record 3 of Set 10 | nalut
# working
# Processing Record 4 of Set 10 | puerto narino
# working
# Processing Record 5 of Set 10 | husavik
# working
# Processing Record 6 of Set 10 | atka
# City not found. Skipping...
# Processing Record 7 of Set 10 | okato
# working
# Processing Record 8 of Set 10 | timra
# working
# Processing Record 9 of Set 10 | west wendover
# working
# Processing Record 10 of Set 10 | karamken
# City not found. Skipping...
# Processing Record 11 of Set 10 | kuching
# working
# Processing Record 12 of Set 10 | balaipungut
# working
# Processing Record 13 of Set 10 | santa barbara
# working
# Processing Record 14 of Set 10 | buritizeiro
# working
# Processing Record 15 of Set 10 | deoria
# working
# Processing Record 16 of Set 10 | pinega
# working
# Processing Record 17 of Set 10 | burns lake
# working
# Processing Record 18 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 19 of Set 10 | kokorevka
# working
# Processing Record 20 of Set 10 | kloulklubed
# working
# Processing Record 21 of Set 10 | lompoc
# working
# Processing Record 22 of Set 10 | egvekinot
# working
# Processing Record 23 of Set 10 | portobelo
# working
# Processing Record 24 of Set 10 | muriti
# working
# Processing Record 25 of Set 10 | sukhumi
# working
# Processing Record 26 of Set 10 | jimenez
# working
# Processing Record 27 of Set 10 | kardasova recice
# working
# Processing Record 28 of Set 10 | pinyug
# working
# Processing Record 29 of Set 10 | aquiraz
# working
# Processing Record 30 of Set 10 | ixtapa
# working
# Processing Record 31 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 32 of Set 10 | palana
# working
# Processing Record 33 of Set 10 | nancha
# working
# Processing Record 34 of Set 10 | prince rupert
# working
# Processing Record 35 of Set 10 | cam ranh
# working
# Processing Record 36 of Set 10 | vila velha
# working
# Processing Record 37 of Set 10 | naron
# working
# Processing Record 38 of Set 10 | saint-francois
# working
# Processing Record 39 of Set 10 | leshukonskoye
# working
# Processing Record 40 of Set 10 | rancho palos verdes
# working
# Processing Record 41 of Set 10 | vao
# working
# Processing Record 42 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 43 of Set 10 | manokwari
# working
# Processing Record 44 of Set 10 | sorong
# working
# Processing Record 45 of Set 10 | kandrian
# working
# Processing Record 46 of Set 10 | surgut
# working
# Processing Record 47 of Set 10 | andenes
# working
# Processing Record 48 of Set 10 | igrim
# working
# Processing Record 49 of Set 10 | santa isabel
# working
# Processing Record 50 of Set 10 | ryotsu
# working
# Processing Record 1 of Set 11 | uruzgan
# working
# Processing Record 2 of Set 11 | sisimiut
# working
# Processing Record 3 of Set 11 | haines junction
# working
# Processing Record 4 of Set 11 | chapais
# working
# Processing Record 5 of Set 11 | alenquer
# working
# Processing Record 6 of Set 11 | gao
# working
# Processing Record 7 of Set 11 | dyurtyuli
# working
# Processing Record 8 of Set 11 | goderich
# working
# Processing Record 9 of Set 11 | talnakh
# working
# Processing Record 10 of Set 11 | batetskiy
# working
# Processing Record 11 of Set 11 | santa comba
# working
# Processing Record 12 of Set 11 | iwanai
# working
# Processing Record 13 of Set 11 | shu
# working
# Processing Record 14 of Set 11 | amapa
# working
# Processing Record 15 of Set 11 | xichang
# working
# Processing Record 16 of Set 11 | tirumullaivasal
# working
# Processing Record 17 of Set 11 | rio gallegos
# working
# Processing Record 18 of Set 11 | yenagoa
# working
# Processing Record 19 of Set 11 | kem
# working
# Processing Record 20 of Set 11 | koslan
# working
# Processing Record 21 of Set 11 | moron
# working
# Processing Record 22 of Set 11 | necochea
# working
# Processing Record 23 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 11 | tiarei
# working
# Processing Record 25 of Set 11 | quatre cocos
# working
# Processing Record 26 of Set 11 | rosetta
# working
# Processing Record 27 of Set 11 | wanning
# working
# Processing Record 28 of Set 11 | erdenet
# working
# Processing Record 29 of Set 11 | svetlyy
# working
# Processing Record 30 of Set 11 | kindu
# working
# Processing Record 31 of Set 11 | karratha
# working
# Processing Record 32 of Set 11 | nishihara
# working
# Processing Record 33 of Set 11 | sigli
# working
# Processing Record 34 of Set 11 | zlobin
# working
# Processing Record 35 of Set 11 | yar-sale
# working
# Processing Record 36 of Set 11 | launceston
# working
# Processing Record 37 of Set 11 | baturaja
# working
# Processing Record 38 of Set 11 | odweyne
# working
# Processing Record 39 of Set 11 | sliven
# working
# Processing Record 40 of Set 11 | woodward
# working
# Processing Record 41 of Set 11 | mana
# working
# Processing Record 42 of Set 11 | beyneu
# working
# Processing Record 43 of Set 11 | wahpeton
# working
# Processing Record 44 of Set 11 | constitucion
# working
# Processing Record 45 of Set 11 | belmonte
# working
# Processing Record 46 of Set 11 | beringovskiy
# working
# Processing Record 47 of Set 11 | prainha
# working
# Processing Record 48 of Set 11 | tahoua
# working
# Processing Record 49 of Set 11 | teknaf
# working
# Processing Record 50 of Set 11 | puerto baquerizo moreno
# working
# Processing Record 1 of Set 12 | kargasok
# working
# Processing Record 2 of Set 12 | pandan
# working
# Processing Record 3 of Set 12 | makakilo city
# working
# Processing Record 4 of Set 12 | sofiysk
# City not found. Skipping...
# Processing Record 5 of Set 12 | dauriya
# working
# Processing Record 6 of Set 12 | port lincoln
# working
# Processing Record 7 of Set 12 | kadoma
# working
# Processing Record 8 of Set 12 | padang
# working
# Processing Record 9 of Set 12 | krasnoselkup
# working
# Processing Record 10 of Set 12 | dicabisagan
# working
# Processing Record 11 of Set 12 | mogadishu
# working
# Processing Record 12 of Set 12 | gambo
# working
# Processing Record 13 of Set 12 | pringsewu
# working
# Processing Record 14 of Set 12 | cholet
# working
# Processing Record 15 of Set 12 | freeport
# working
# Processing Record 16 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 12 | beruwala
# working
# Processing Record 18 of Set 12 | lynn haven
# working
# Processing Record 19 of Set 12 | masakin
# working
# Processing Record 20 of Set 12 | murray bridge
# working
# Processing Record 21 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 12 | ostrovnoy
# working
# Processing Record 23 of Set 12 | opuwo
# working
# Processing Record 24 of Set 12 | novoagansk
# working
# Processing Record 25 of Set 12 | bosaso
# working
# Processing Record 26 of Set 12 | sherlovaya gora
# working
# Processing Record 27 of Set 12 | roquetas de mar
# working
# Processing Record 28 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 29 of Set 12 | nabire
# working
# Processing Record 30 of Set 12 | nelson bay
# working
# Processing Record 31 of Set 12 | maniitsoq
# working
# Processing Record 32 of Set 12 | yarim
# working
# Processing Record 33 of Set 12 | carolina
# working
# Processing Record 34 of Set 12 | cocobeach
# working
# Processing Record 35 of Set 12 | san rafael
# working
# Processing Record 36 of Set 12 | jasper
# working
# Processing Record 37 of Set 12 | fukue
# working
# Processing Record 38 of Set 12 | gazli
# working
# Processing Record 39 of Set 12 | wajima
# working
# Processing Record 40 of Set 12 | iracoubo
# working
# Processing Record 41 of Set 12 | juruti
# working
# Processing Record 42 of Set 12 | road town
# working
# Processing Record 43 of Set 12 | jibuti
# working
# Processing Record 44 of Set 12 | balikpapan
# working
# Processing Record 45 of Set 12 | tansen
# working
# Processing Record 46 of Set 12 | una
# working
# Processing Record 47 of Set 12 | bagaces
# working
# Processing Record 48 of Set 12 | plouzane
# working
# Processing Record 49 of Set 12 | jizan
# working
# Processing Record 50 of Set 12 | yialos
# City not found. Skipping...
# Processing Record 1 of Set 13 | big spring
# working
# Processing Record 2 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 13 | salinas
# working
# Processing Record 4 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 5 of Set 13 | promyshlennaya
# working
# Processing Record 6 of Set 13 | nioro
# working
# Processing Record 7 of Set 13 | smithers
# working
# Processing Record 8 of Set 13 | ballina
# working
# Processing Record 9 of Set 13 | liberty
# working
# Processing Record 10 of Set 13 | bucerias
# working
# Processing Record 11 of Set 13 | teahupoo
# working
# Processing Record 12 of Set 13 | xuddur
# working
# Processing Record 13 of Set 13 | los llanos de aridane
# working
# Processing Record 14 of Set 13 | salalah
# working
# Processing Record 15 of Set 13 | buta
# working
# Processing Record 16 of Set 13 | pavelets
# working
# Processing Record 17 of Set 13 | port blair
# working
# Processing Record 18 of Set 13 | superior
# working
# Processing Record 19 of Set 13 | wangdiphodrang
# City not found. Skipping...
# Processing Record 20 of Set 13 | ordubad
# working
# Processing Record 21 of Set 13 | covington
# working
# Processing Record 22 of Set 13 | hofn
# working
# Processing Record 23 of Set 13 | fougeres
# working
# Processing Record 24 of Set 13 | te anau
# working
# Processing Record 25 of Set 13 | patterson
# working
# Processing Record 26 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 13 | zhuhai
# working
# Processing Record 28 of Set 13 | hobyo
# working
# Processing Record 29 of Set 13 | bima
# working
# Processing Record 30 of Set 13 | mashhad
# working
# Processing Record 31 of Set 13 | guiren
# working
# Processing Record 32 of Set 13 | oktyabrskoye
# working
# Processing Record 33 of Set 13 | nipawin
# working
# Processing Record 34 of Set 13 | rambouillet
# working
# Processing Record 35 of Set 13 | jardim
# working
# Processing Record 36 of Set 13 | keetmanshoop
# working
# Processing Record 37 of Set 13 | lamar
# working
# Processing Record 38 of Set 13 | namibe
# working
# Processing Record 39 of Set 13 | agadez
# working
# Processing Record 40 of Set 13 | yucca valley
# working
# Processing Record 41 of Set 13 | pemba
# working
# Processing Record 42 of Set 13 | carmarthen
# working
# Processing Record 43 of Set 13 | brzeg dolny
# working
# Processing Record 44 of Set 13 | plainfield
# working
# Processing Record 45 of Set 13 | ambatondrazaka
# working
# Processing Record 46 of Set 13 | vila
# working
# Processing Record 47 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 48 of Set 13 | honningsvag
# working
# Processing Record 49 of Set 13 | baiquan
# working
# Processing Record 50 of Set 13 | coihaique
# working
# Processing Record 1 of Set 14 | hualmay
# working
# Processing Record 2 of Set 14 | poum
# working
# Processing Record 3 of Set 14 | narsipatnam
# working
# Processing Record 4 of Set 14 | kuusamo
# working
# Processing Record 5 of Set 14 | kulhudhuffushi
# working
# Processing Record 6 of Set 14 | wyndham
# working
# Processing Record 7 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 14 | harlingen
# working
# Processing Record 9 of Set 14 | vila franca do campo
# working
# Processing Record 10 of Set 14 | camacha
# working
# Processing Record 11 of Set 14 | kolondieba
# working
# Processing Record 12 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 13 of Set 14 | carberry
# working
# Processing Record 14 of Set 14 | rawson
# working
# Processing Record 15 of Set 14 | xingcheng
# working
# Processing Record 16 of Set 14 | buan
# working
# Processing Record 17 of Set 14 | sioux lookout
# working
# Processing Record 18 of Set 14 | verkh-usugli
# working
# Processing Record 19 of Set 14 | kavieng
# working
# Processing Record 20 of Set 14 | amursk
# working
# Processing Record 21 of Set 14 | kieta
# working
# Processing Record 22 of Set 14 | eustis
# working
# Processing Record 23 of Set 14 | pacific grove
# working
# Processing Record 24 of Set 14 | garissa
# working
# Processing Record 25 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 26 of Set 14 | tezu
# working
# Processing Record 27 of Set 14 | wiarton
# working
# Processing Record 28 of Set 14 | mmabatho
# working
# Processing Record 29 of Set 14 | adrar
# working
# Processing Record 30 of Set 14 | moose jaw
# working
# Processing Record 31 of Set 14 | weymouth
# working
# Processing Record 32 of Set 14 | abha
# working
# Processing Record 33 of Set 14 | kuytun
# working
# Processing Record 34 of Set 14 | praia
# working
# Processing Record 35 of Set 14 | stephanskirchen
# working
# Processing Record 36 of Set 14 | tateyama
# working
# Processing Record 37 of Set 14 | wageningen
# working
# Processing Record 38 of Set 14 | rocha
# working
# Processing Record 39 of Set 14 | bandarbeyla
# working
# Processing Record 40 of Set 14 | nanyang
# working
# Processing Record 41 of Set 14 | port victoria
# working
# Processing Record 42 of Set 14 | breznice
# working
# Processing Record 43 of Set 14 | abilene
# working
# Processing Record 44 of Set 14 | kaniama
# working
# Processing Record 45 of Set 14 | olafsvik
# working
# Processing Record 46 of Set 14 | harper
# working
# Processing Record 47 of Set 14 | ranong
# working
# Processing Record 48 of Set 14 | samana
# working
# Processing Record 49 of Set 14 | kungurtug
# working
# Processing Record 50 of Set 14 | abonnema
# working
# Processing Record 1 of Set 15 | fare
# working
# Processing Record 2 of Set 15 | iranshahr
# working
# Processing Record 3 of Set 15 | linxia
# working
# Processing Record 4 of Set 15 | riverton
# working
# Processing Record 5 of Set 15 | ghotki
# working
# Processing Record 6 of Set 15 | kenai
# working
# Processing Record 7 of Set 15 | orta nova
# working
# Processing Record 8 of Set 15 | castellammare del golfo
# working
# Processing Record 9 of Set 15 | dunedin
# working
# Processing Record 10 of Set 15 | kerema
# working
# Processing Record 11 of Set 15 | loandjili
# working
# Processing Record 12 of Set 15 | taoudenni
# working
# Processing Record 13 of Set 15 | orje
# working
# Processing Record 14 of Set 15 | ormara
# working
# Processing Record 15 of Set 15 | kropotkin
# working
# Processing Record 16 of Set 15 | belaya
# working
# Processing Record 17 of Set 15 | ladario
# working
# Processing Record 18 of Set 15 | whitehorse
# working
# Processing Record 19 of Set 15 | waingapu
# working
# Processing Record 20 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 15 | manono
# working
# Processing Record 22 of Set 15 | peniche
# working
# Processing Record 23 of Set 15 | nushki
# working
# Processing Record 24 of Set 15 | falmouth
# working
# Processing Record 25 of Set 15 | batagay-alyta
# working
# Processing Record 26 of Set 15 | soligalich
# working
# Processing Record 27 of Set 15 | rio do sul
# working
# Processing Record 28 of Set 15 | lodeynoye pole
# working
# Processing Record 29 of Set 15 | korla
# working
# Processing Record 30 of Set 15 | ugoofaaru
# working
# Processing Record 31 of Set 15 | itarema
# working
# Processing Record 32 of Set 15 | palu
# working
# Processing Record 33 of Set 15 | salina
# working
# Processing Record 34 of Set 15 | mitsamiouli
# working
# Processing Record 35 of Set 15 | zubtsov
# working
# Processing Record 36 of Set 15 | shellbrook
# working
# Processing Record 37 of Set 15 | nizwa
# working
# Processing Record 38 of Set 15 | asau
# working
# Processing Record 39 of Set 15 | paracuru
# working
# Processing Record 40 of Set 15 | vangaindrano
# working
# Processing Record 41 of Set 15 | jinchang
# working
# Processing Record 42 of Set 15 | qasigiannguit
# working
# Processing Record 43 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 44 of Set 15 | constantine
# working
# Processing Record 45 of Set 15 | rundu
# working
# Processing Record 46 of Set 15 | rio bueno
# working
# Processing Record 47 of Set 15 | venice
# working
# Processing Record 48 of Set 15 | suslovo
# working
# Processing Record 49 of Set 15 | bunol
# working
# Processing Record 50 of Set 15 | isfana
# working
# Processing Record 1 of Set 16 | grand-lahou
# working
# Processing Record 2 of Set 16 | okhotsk
# working
# Processing Record 3 of Set 16 | luanda
# working
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
print(len(city_data))
# Out:
# 704

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hasaki  35.7333  140.8333     39.22        59          99
# 1     Omsukchan  62.5333  155.8000    -31.79        94         100
# 2  Punta Arenas -53.1500  -70.9167     66.31        52           0
# 3  Puerto Ayora  -0.7393  -90.3518     76.55        92          90
# 4        Hobart -42.8794  147.3294     61.05        55          75
# 5         Sitka  57.0531 -135.3300     39.09        75         100
# 6   New Norfolk -42.7826  147.0587     60.71        48          42
# 7    Nikolskoye  59.7035   30.7861     33.80        98         100
# 8       Rikitea -23.1203 -134.9692     77.99        70          75
# 9       Ushuaia -54.8000  -68.3000     64.36        64          78
#
#    Wind Speed Country Weather Description
# 0       16.58      JP     overcast clouds
# 1        5.53      RU     overcast clouds
# 2       19.57      CL           clear sky
# 3        4.00      EC     overcast clouds
# 4       13.80      AU       broken clouds
# 5       13.80      US          light rain
# 6        4.00      AU    scattered clouds
# 7        9.22      RU          light snow
# 8        3.18      PF       broken clouds
# 9        3.74      AR       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Weather Description"]

# Recreate the DataFrame by using the new column order
city_data_df =city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hasaki      JP  35.7333  140.8333     39.22        59          99
# 1     Omsukchan      RU  62.5333  155.8000    -31.79        94         100
# 2  Punta Arenas      CL -53.1500  -70.9167     66.31        52           0
# 3  Puerto Ayora      EC  -0.7393  -90.3518     76.55        92          90
# 4        Hobart      AU -42.8794  147.3294     61.05        55          75
# 5         Sitka      US  57.0531 -135.3300     39.09        75         100
# 6   New Norfolk      AU -42.7826  147.0587     60.71        48          42
# 7    Nikolskoye      RU  59.7035   30.7861     33.80        98         100
# 8       Rikitea      PF -23.1203 -134.9692     77.99        70          75
# 9       Ushuaia      AR -54.8000  -68.3000     64.36        64          78
#
#    Wind Speed Weather Description
# 0       16.58     overcast clouds
# 1        5.53     overcast clouds
# 2       19.57           clear sky
# 3        4.00     overcast clouds
# 4       13.80       broken clouds
# 5       13.80          light rain
# 6        4.00    scattered clouds
# 7        9.22          light snow
# 8        3.18       broken clouds
# 9        3.74       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
